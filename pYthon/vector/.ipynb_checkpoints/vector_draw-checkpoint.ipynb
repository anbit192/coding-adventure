# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

# %%
X, Y = np.meshgrid(np.linspace(2,0,20),np.linspace(0,2,20))

U = X*Y
V = (X**2)*(Y**2)

plt.quiver(X,Y,U,V,color=None)
plt.plot([2,0],[0,2],color='red')

plt.grid()
plt.show()
